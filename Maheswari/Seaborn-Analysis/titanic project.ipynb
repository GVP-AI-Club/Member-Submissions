# %%
import pandas as pd
import seaborn as sns
import matplotlit.typlot as plt
# %matplotlit inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-320e7d6b9c10> in <module>()
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 3 import matplotlit.typlot as plt
#       4 get_ipython().run_line_magic('matplotlit', 'inline')
#       5
#
# ModuleNotFoundError: No module named 'matplotlit'

# %%
# !conda install seaborn --yes

# %%
tit= pd.read_csv('titanic.csv', index_col=3, sep = '\,')
# Out:
# c:\new folder\python_u\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
tit
# Out:
#                   PassengerId  Survived  Pclass  \
# "Braund                     1         0       3
# "Cumings                    2         1       1
# "Heikkinen                  3         1       3
# "Futrelle                   4         1       1
# "Allen                      5         0       3
# "Moran                      6         0       3
# "McCarthy                   7         0       1
# "Palsson                    8         0       3
# "Johnson                    9         1       3
# "Nasser                    10         1       2
# "Sandstrom                 11         1       3
# "Bonnell                   12         1       1
# "Saundercock               13         0       3
# "Andersson                 14         0       3
# "Vestrom                   15         0       3
# "Hewlett                   16         1       2
# "Rice                      17         0       3
# "Williams                  18         1       2
# ...

# %%
sns.lmplot(x= 'Age', y= 'Fare', data = tit)
# Out:
# c:\new folder\python_u\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
tit.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ok)
# Out:
#   File "<ipython-input-10-9e49b51b465e>", line 1
#     ok)
#       ^
# SyntaxError: invalid syntax

# %%
sns.violinplot(x = 'Age', y = 'Fare', data = tit)
plt.xticks(rotation = -45)
# Out:
# c:\new folder\python_u\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1a1b4fc974b8> in <module>()
#       1 sns.violinplot(x = 'Age', y = 'Fare', data = tit)
# ----> 2 plt.xticks(rotation = -45)
#
# NameError: name 'plt' is not defined

# %%
sns.swarmplot(x = 'Age', y = 'Fare', data = tit)
plt.xticks(rotation = -45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-acb386eff657> in <module>()
#       1 sns.swarmplot(x = 'Age', y = 'Fare', data = tit)
# ----> 2 plt.xticks(rotation = -45)
#
# NameError: name 'plt' is not defined

# %%
col = list(tit.columns)
stats_df = tit[col[4:-2]]
#Correlation of the different varibles can be known by ".corr()" function on pandas dataframe.
corr = stats_df.corr()
sns.heatmap(corr)

# %%
sns.distplot(tit['Fare'], kde= False)
# Out:
# c:\new folder\python_u\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot(x = 'Fare', data = tit)
plt.xticks(rotation = -45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e008f63ed3a3> in <module>()
#       1 sns.countplot(x = 'Fare', data = tit)
# ----> 2 plt.xticks(rotation = -45)
#
# NameError: name 'plt' is not defined
