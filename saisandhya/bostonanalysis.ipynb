# %%
import pandas as pd
import seaborn as sns
import missingno as ms
import matplotlib.pyplot as mat
import sklearn as skl
import numpy as np

# %%
bds = pd.read_csv('btrain.csv')
bds2 = bds

# %%
bds.head(10)
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 3   5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# 4   7  0.08829  12.5   7.87     0  0.524  6.012  66.6  5.5605    5  311
# 5  11  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311
# 6  12  0.11747  12.5   7.87     0  0.524  6.009  82.9  6.2267    5  311
# 7  13  0.09378  12.5   7.87     0  0.524  5.889  39.0  5.4509    5  311
# 8  14  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307
# 9  15  0.63796   0.0   8.14     0  0.538  6.096  84.5  4.4619    4  307
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
# 3     18.7  396.90   5.33  36.2
# ...

# %%
bds.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %%
ms.matrix(bds)

# %%
#Pandas slicing the dataframe.
col = list(bds.columns)
stats_df = bds[col[:]]
#Correlation of the different varibles can be known by ".corr()" function on pandas dataframe.
corr = stats_df.corr()
sns.heatmap(corr)

# %%
sns.swarmplot(x = 'medv', y = 'rm', data = bds)

# %%
bds = bds.drop('lstat', axis=1)

# %%
ms.matrix(bds)

# %%
bds
# Out:
#       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1      2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2      4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 3      5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 5     11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 6     12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 7     13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 8     14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 9     15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 10    16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# ...

# %%
y = bds.medv

# %%
X=bds.drop(['medv'], axis=1)

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      33.4
# 3      36.2
# 4      22.9
# 5      15.0
# 6      18.9
# 7      21.7
# 8      20.4
# 9      18.2
# 10     19.9
# 11     23.1
# 12     20.2
# 13     13.6
# 14     19.6
# 15     15.2
# 16     14.5
# 17     14.8
# 18     12.7
# 19     14.5
# 20     13.5
# 21     24.7
# 22     30.8
# 23     34.9
# 24     25.3
# 25     24.7
# 26     21.2
# 27     19.3
# 28     20.0
# 29     16.6
#        ...
# 303    21.4
# 304    19.9
# 305    19.0
# 306    19.1
# 307    19.1
# 308    20.1
# 309    19.6
# 310    23.2
# 311    13.8
# 312    16.7
# 313    12.0
# 314    14.6
# 315    21.4
# 316    23.0
# 317    23.7
# 318    21.8
# 319    20.6
# 320    19.1
# 321    20.6
# 322    15.2
# 323     8.1
# 324    13.6
# 325    20.1
# 326    21.8
# 327    18.3
# 328    17.5
# 329    22.4
# 330    20.6
# 331    23.9
# 332    11.9
# Name: medv, Length: 333, dtype: float64

# %%
X
# Out:
#       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1      2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2      4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 3      5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 5     11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 6     12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 7     13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 8     14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 9     15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 10    16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
boston_model = DecisionTreeRegressor(random_state=1)

# %%
boston_model.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=1, splitter='best')

# %%
print("The predictions are")
print(boston_model.predict(X.head()))
# Out:
# The predictions are
# [24.  21.6 33.4 36.2 22.9]

# %%
btest = pd.read_csv('btest.csv')

# %%
btest.head(10)
# Out:
#    ID     crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0   3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 1   6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 2   8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 3   9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 4  10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 5  18  0.78420   0.0   8.14     0  0.538  5.990   81.7  4.2579    4  307
# 6  20  0.72580   0.0   8.14     0  0.538  5.727   69.5  3.7965    4  307
# 7  25  0.75026   0.0   8.14     0  0.538  5.924   94.1  4.3996    4  307
# 8  26  0.84054   0.0   8.14     0  0.538  5.599   85.7  4.4546    4  307
# 9  27  0.67191   0.0   8.14     0  0.538  5.813   90.3  4.6820    4  307
#
#    ptratio   black  lstat
# 0     17.8  392.83   4.03
# 1     18.7  394.12   5.21
# 2     15.2  396.90  19.15
# 3     15.2  386.63  29.93
# 4     15.2  386.71  17.10
# ...

# %%
btest = btest.drop('lstat',axis=1)

# %%
test1 = boston_model.predict(btest)
#        19.45636414, 21.2296407 , 15.13868618, 15.11996785, 22.93869901,
#        22.43005481, 22.9524457 , 29.59034087, 15.37046802, 27.40966474,
#        20.0454272 , 21.59860388, 20.50608268, 23.15072763, 22.70960176,
#        22.5390532 , 25.8078573 , 26.43146508, 28.35750243, 28.1315965 ,
#        36.69103929, 37.39757012, 33.39591253, 21.25269924, 19.45878004,
#        22.88554811, 21.91725837, 22.54889387, 21.31295601, 21.53520699,
#        14.53750059, 19.24645481, 18.19777937, 18.46723179, 18.55536262,
#        15.62716194, 12.55133414, 13.30864754, 14.4690127 , 16.84507777,
#        19.78432595, 29.54765499, 38.93857137, 24.0758257 , 21.37720967,
#        25.47837807, 31.9183532 , 41.78159734, 35.6483454 , 35.23876162,
#        30.13460849, 38.22234918, 19.36063589, 20.00374099, 24.31614428,
# ...

# %%
np.savetxt("boston_submission22.csv", test2, delimiter=",")

# %%
bds2
# Out:
#       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1      2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2      4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 3      5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 5     11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 6     12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 7     13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 8     14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 9     15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 10    16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# ...

# %%
y2 = bds2.medv

# %%
X2 = bds2.drop('medv',axis=1)
X2
# Out:
#       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      1   0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
# 1      2   0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242
# 2      4   0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222
# 3      5   0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222
# 4      7   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 5     11   0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 6     12   0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 7     13   0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 8     14   0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 9     15   0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
# 10    16   0.62739   0.0   8.14     0  0.538  5.834   56.5  4.4986    4  307
# ...

# %%
boston_model2 = LinearRegression()

# %%
boston_model2.fit(X2,y2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
btest2 = pd.read_csv('btest.csv')

# %%
btest2
# Out:
#       ID      crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 0      3   0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242
# 1      6   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 2      8   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 3      9   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 4     10   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 5     18   0.78420   0.0   8.14     0  0.538  5.990   81.7  4.2579    4  307
# 6     20   0.72580   0.0   8.14     0  0.538  5.727   69.5  3.7965    4  307
# 7     25   0.75026   0.0   8.14     0  0.538  5.924   94.1  4.3996    4  307
# 8     26   0.84054   0.0   8.14     0  0.538  5.599   85.7  4.4546    4  307
# 9     27   0.67191   0.0   8.14     0  0.538  5.813   90.3  4.6820    4  307
# 10    29   0.77299   0.0   8.14     0  0.538  6.495   94.4  4.4547    4  307
# ...

# %%
test4 = boston_model2.predict(btest2)
test4
# Out:
# array([31.27947429, 25.64467092, 18.66939919,  9.70469293, 18.18776827,
#        17.25721236, 19.17726072, 15.73496669, 13.24982207, 15.5718257 ,
#        19.86982974, 21.36318328,  7.7493535 , 14.12561852, 24.37918489,
#        22.78142834, 23.92830169, 28.95121883,  6.98337459, 28.13150174,
#        21.49340364, 24.3633102 , 21.0157493 , 22.27629255, 21.48174445,
#        23.1349735 , 26.53357032, 27.40764862, 29.63245149, 28.66678691,
#        36.01716279, 35.76571544, 32.41445524, 21.78926285, 18.52394786,
#        21.24472516, 20.6427661 , 20.48508635, 20.22964004, 22.77639638,
#        14.56069361, 20.93906783, 21.03828501, 17.81868028, 13.61749515,
#        12.01152334,  8.28275913, 15.72540189, 18.82390015, 21.90036804,
#        21.23938497, 33.93579311, 42.64212385, 26.35818872, 21.59393999,
#        23.90512336, 32.5148109 , 40.69463756, 35.37480505, 33.69092227,
#        30.03049353, 36.9894938 , 16.80662396, 16.43691169, 22.36650512,
# ...

# %%
np.savetxt("boston_submission4.csv", test4, delimiter=",")
